# %%
import template
import tools
import numpy as np
import matplotlib.pyplot as plt

# %%
features, targets, classes = tools.load_iris()
template.brute_best_split(features, targets, classes, 30)
# Out:
# (0.16666666666666666, 2, 1.9516129032258065)

# %%
model = template.IrisTreeTrainer(features, targets)
model.train()

# %%
model.accuracy()
# Out:
# 0.9655172413793104

# %%
model.plot()

# %%
model.guess()
# Out:
# array([0, 0, 1, 1, 0, 0, 0, 1, 2, 2, 1, 1, 0, 2, 2, 1, 2, 2, 1, 0, 0, 2,
#        1, 0, 2, 2, 2, 0, 2])

# %%
model.test_targets
# Out:
# array([0, 0, 1, 1, 0, 0, 0, 1, 2, 2, 1, 1, 0, 2, 2, 2, 2, 2, 1, 0, 0, 2,
#        1, 0, 2, 2, 2, 0, 2])

# %%
model.confusion_matrix()
# Out:
# array([[10,  0,  0],
#        [ 0,  7,  0],
#        [ 0,  1, 11]])
