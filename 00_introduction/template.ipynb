# %%
import numpy as np
import matplotlib.pyplot as plt

from template import *

# %%
print(normal(0, 1, 0))
print(normal(3, 1, 5))
print(normal(np.array([-1,0,1]), 1, 0))
# Out:
# 0.3989422804014327
# 0.05399096651318806
# [0.24197072 0.39894228 0.24197072]

# %%
plot_normal(0.5, 0, -2, 2)

# %%
plot_three_normals()
plt.savefig('plots/1_2_1.png')

# %%
print(normal_mixture(np.linspace(-5, 5, 5), [0.5, 0.25, 1], [0, 1, 1.5], [1/3, 1/3, 1/3]))
print(normal_mixture(np.linspace(-2, 2, 4), [0.5], [0], [1]))
# Out:
# [8.89852205e-11 4.56012216e-05 3.09312492e-01 8.06579074e-02
#  2.90894232e-04]
# [2.67660452e-04 3.28020149e-01 3.28020149e-01 2.67660452e-04]

# %%
compare_components_and_mixture()
plt.savefig('plots/2_2_1.png')

# %%
np.random.seed(0)
print(sample_gaussian_mixture([0.1, 1], [-1, 1], [0.9, 0.1], 3))
print(sample_gaussian_mixture([0.1, 1, 1.5], [1, -1, 5], [0.1, 0.1, 0.8], 10))
# Out:
# [-0.92584083 -0.84470863 -1.22683282]
# [1.13335454 0.26611853 4.24118519 8.81780117 6.62121787 5.72646823
#  5.86871072 4.72762614 7.11530695 4.43829246]

# %%
plot_mixture_and_samples()
plt.savefig('plots/3_2_1.png')
